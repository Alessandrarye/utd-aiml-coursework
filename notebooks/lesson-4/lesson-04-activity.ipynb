# %% [markdown]
# # Lesson 04 activity: data types and operators
#
# In this activity, you'll solve four problems that build on what you've learned in Lesson 04. However, these problems will require you to **research**, **explore**, and **discover** Python methods and techniques not directly covered in the demonstration notebooks.
#
# ## Instructions:
# - Each problem has a clear objective
# - You may need to use Google, Python documentation, or experimentation
# - Test your solutions in the code cells provided
# - There are multiple ways to solve each problem - be creative!

# %% [markdown]
# ---
# ## Problem 1: The word splitter
#
# **Your Task:**
# - Research string methods that can break a sentence into parts
# - Split the string `text` into a list of words and store it in a variable called `word_list`
# - Print both the original sentence and the list of words
# - Print the number of words in the sentence

# %%
# Problem 1: Your solution here
text = 'Python is awesome!'

# Write your code below

word_list = text.split()

print("Original sentence:", text)
print("List of words:", word_list)
print("Number of words:", len(word_list))
# Out:
# Original sentence: Python is awesome!
# List of words: ['Python', 'is', 'awesome!']
# Number of words: 3

# %% [markdown]
# ---
# ## Problem 2: The dictionary saver
#
# **Your Task:**
# 1. Save the `student_data` dictionary to a file
# 2. Load the data back from the file into a new dictionary called `loaded_data`
# 3. Print both the original and loaded dictionaries to verify they match
# 4. Use error handling to manage any potential issues
#
# **Hint:** JSON (JavaScript Object Notation) is a popular format for storing structured data.

# %%
# Problem 2: Your solution here

# Given dictionary
student_data = {
    'name': 'Alice',
    'age': 22,
    'courses': ['Python', 'Data Science', 'Machine Learning'],
    'grade': 'A'
}

# Write your code below to save and load the 

# Import the json module
import json

# Save the dictionary to a file
with open("student_data.json", "w") as file:
    json.dump(student_data, file)

# Load the dictionary back from the file
with open("student_data.json", "r") as file:
    loaded_data = json.load(file)

# Print both dictionaries to verify they match
print("Original dictionary:", student_data)
print("Loaded dictionary:", loaded_data)
# Out:
# Original dictionary: {'name': 'Alice', 'age': 22, 'courses': ['Python', 'Data Science', 'Machine Learning'], 'grade': 'A'}
# Loaded dictionary: {'name': 'Alice', 'age': 22, 'courses': ['Python', 'Data Science', 'Machine Learning'], 'grade': 'A'}

# %% [markdown]
# ---
# ## Problem 3: The safe list accessor
#
# **Your Task:**
# 1. Use a `try/except` block to access index `2` from `my_list`. Store the result in a variable called `item_2`.
# 2. Use a `try/except` block to access index `10` from `my_list`. If the index doesn't exist, store `'Not found'` in a variable called `item_10`.
# 3. Use a `try/except` block to access index `-1` from `my_list`. Store the result in a variable called `item_last`.
# 4. Print all three variables.
#
# **Expected output:**
# ```
# Item at index 2: cherry
# Item at index 10: Not found
# Item at index -1: elderberry
# ```
#
# **Hint:** Use `IndexError` in your `except` clause.

# %%
# Problem 3: Your solution here

my_list = ['apple', 'banana', 'cherry', 'date', 'elderberry']

# Access index 2 safely
try:
    item_2 = my_list[2]
except IndexError:
    item_2 = 'Not found'
    pass
except IndexError:
    pass

# Access index 10 safely (store 'Not found' if it doesn't exist)
try:
    item_10 = my_list[10]
except IndexError:
    item_10 = 'Not found'
    pass
except IndexError:
    pass

# Access index -1 safely
try:
    item_last = my_list[-1]
except IndexError:
    item_last = 'Not found'
    pass
except IndexError:
    pass

print('Item at index 2:', item_2)
print('Item at index 10:', item_10)
print('Item at index -1:', item_last)
# Out:
# Item at index 2: cherry
# Item at index 10: Not found
# Item at index -1: elderberry

# %% [markdown]
# ---
# ## Problem 4: Fixing bugs
#
# **Objective:** Debug and fix code snippets that contain common Python errors.
#
# **Your Task:**
# Below are several code snippets that contain bugs. For each one:
# 1. Identify the error
# 2. Fix the code
# 3. Test that it works correctly
# 4. Add a comment explaining what was wrong
#
# Run each fixed snippet to verify it works!

# %% [markdown]
# ### Bug 1
#
# **Expected output:** `Hello, World!`

# %%
# Bug 1: Fix the code below
# Error: The text was missing quotation marks, so Python did not know it was a string.

print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# ### Bug 2
#
# **Expected behavior:** Should catch the error and print `Error: Cannot divide by zero!` without crashing

# %%
# Bug 2: Fix the code below
# Error: The code was dividing by zero, which causes a ZeroDivisionError

numerator = 10
denominator = 0

try:
    result = numerator / denominator
    print(f'Result: {result}')

except ZeroDivisionError:
    print('Error: Cannot divide by zero!')
# Out:
# Error: Cannot divide by zero!

# %% [markdown]
# ### Bug 3
#
# **Expected behavior:** Should handle an empty list gracefully without crashing

# %%
# Bug 3: Fix the code below
# Error: The list is empty, so dividing by len(scores causes a ZeroDivisionError.)

scores = []

if len(scores) > 0:
    total = sum(scores)
    average = total / len(scores)
    print(f'Average score: {average}')
else:
    print('No scores available')
# Out:
# No scores available

# %% [markdown]
# ### Bug 4
#
# **Expected behavior:** Should correctly calculate age + 1 (Hint: What type does `input()` return?)

# %%
# Bug 4: Fix the code below
# Error: input() returns a string, so it must be converted to an integer before adding 1.

age = int(input('Enter your age: '))
next_year_age = age + 1
print(f'Next year you will be {next_year_age}')
# Out:
# Next year you will be 23

# %% [markdown]
# ### Bug 5
#
# **Expected behavior:** Should handle the list access safely or explain why it fails

# %%
# Bug 5: Fix the code below
# Error: The list only has indexes 0, 1, and 2, so index 3 does not exist.

fruits = ['apple', 'banana', 'cherry']

try:
    print(f'The fourth fruit is: {fruits[3]}')
except IndexError:

    print('There is no fourth fruit in the list.')
# Out:
# There is no fourth fruit in the list.

# %% [markdown]
# ---
# ## __Reflection questions__
#
# After completing the scavenger hunt, answer these questions:
#
# 1. What resources did you use to find solutions? (Documentation, Stack Overflow, etc.)
# 2. Which problem was most challenging? Why?
# 3. What new Python feature or method did you find most interesting?
# 4. How did you approach debugging when your code didn't work initially?

# %% [markdown]
# ## Reflection Questions:
#
# **1. What resources did you use to find solutions?**
#
# Besides the assignment directions, I used the Python error messages, and the book Learning Python by Mark Lutz from O'Reilly. Knowing the specific tasks I needed to complete, and the error messages when something went wrong, helped me figure out what didn't work or where to go look for answers.
#
# **2. Which problem was most challenging? Why?**
#
# The debugging section was the most challenging because some of the errors were not just about fixing one word. I had to understand why the code was failing before I could fix it. For example, with the list index probme, I had to remember that Python starts counting at 0, so a list with three items only has indexes 0, 1, amd 2. I also had to pay close attention to indentation because Python depends on spacing for "try/except" blocks.
#
# **3. What new Python feature or method di you find most interesting?**
#
# The feature I found most interesting was the "try/except" block.
#
# **4. How did you approach debugging when your code didn't work initially?**
#
# When my code didn't work at first, I looked at the error message and the line number Python gave me. Then I checked that part of the coe carefully to see what Python was trying to tell me. I learned that small details matter a log, such as capitalization, quoatation marks, indentation, and whether a variable has been created before trying to use it.
